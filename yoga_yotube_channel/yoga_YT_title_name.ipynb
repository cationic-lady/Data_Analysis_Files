# %% [markdown]
# # Decoding Yoga Video Trends: Insights from YouTube Data
#
# *This project uses the dataset provided by Ulrike Herold on [Kaggle](https://www.kaggle.com/datasets/ulrikeherold/youtube-channel-yoga-with-kassandra/data) under the CC BY-NC-SA 4.0 license.*

# %%
# necessary imports
import pandas as pd

# %% [markdown]
# #### **Impact of Video Titles:** Do video titles significantly impact engagement metrics? If so, can NLP techniques reveal patterns in successful titles?
#
# Plan of action:
# * I will extract the keywords from each title and then analyse their metrics - frequency, mean engagement ratio, etc.
# * Save this dataframe.
# * Use it for data analysis to understand how title keywords impact the channel's engagement.

# %%
df = pd.read_csv("youtube_yoga.csv")
df.head()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 85
#           channelTitle      videoId  \
# 0  Yoga with Kassandra  6INXj5B5uqE
# 1  Yoga with Kassandra  I9YJA0zL4yg
# 2  Yoga with Kassandra  XcXDqvQXgIs
# 3  Yoga with Kassandra  C2RAjUEAoLI
# 4  Yoga with Kassandra  bN5l0JJTOLw
#
#                                           videoTitle        yogaSubject  \
# 0    15 min Morning Yoga Flow - All Levels, No Props       Morning Yoga
# 1  25 min Earth Element Yoga - Grounding, Strengt...        Zodiac yoga
# 2  25 min Fire Element Yoga Flow - Core, Twists &...        Zodiac yoga
# 3  10 min Gentle Morning Yoga for Beginners (NO P...       Morning Yoga
# 4  20 min Intermediate Yoga Flow - Minimal Cues S...  Intermediate Yoga
#
#    YogaChallenge release_date release_time duration  viewCount  likeCount  \
# 0          False   2024-03-11     10:15:00    17:08      72861       4585
# 1          False   2024-03-04     11:15:01    25:23      69360       4239
# 2          False   2024-02-26     11:15:01    24:52      63923       3142
# 3          False   2024-02-19     11:15:00    11:18     161923       6662
# 4          False   2024-02-12     11:15:04    21:20      72164       4237
#
#    commentCount defaultLAudioLanguage videoCategoryLabel
# 0         282.0                    en      Howto & Style
# 1         266.0                    en      Howto & Style
# 2         206.0                    en      Howto & Style
# 3         180.0                    en      Howto & Style
# 4         279.0                    en      Howto & Style

# %%
# any null values?
df.isna().sum()
# Out:
# channelTitle             0
# videoId                  0
# videoTitle               0
# yogaSubject              0
# YogaChallenge            0
# release_date             0
# release_time             0
# duration                 0
# viewCount                0
# likeCount                0
# commentCount             2
# defaultLAudioLanguage    0
# videoCategoryLabel       0
# dtype: int64

# %%
# it can be assumed that 2 missing comment counts mean that there are no comments on those videos
df['commentCount'] = df['commentCount'].fillna(0)

# introducing the Engagement Ratio = (comments+likes)/views columns

df['engagement_ratio'] = (df['likeCount']+df['commentCount'])/df['viewCount']

# also, i noticed that the release date is in descending order 
# let's rearrange our dataset in a chronological order

df = df.sort_values('release_date', ascending=True)
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#           channelTitle      videoId  \
# 0  Yoga with Kassandra  YgeUkk1V_YA
# 1  Yoga with Kassandra  BbRroBq1I78
# 2  Yoga with Kassandra  Apn9IOQMrns
# 3  Yoga with Kassandra  4EUUNRfdlhw
# 4  Yoga with Kassandra  ebV0f8h800U
#
#                                           videoTitle        yogaSubject  \
# 0                          Yoga Timelapse - Fidelity              Other
# 1  Intermediate Yoga Core Workout - 30 min Vinyas...  Intermediate Yoga
# 2  1 Hour Yin Yoga - Beginners Full Body Yoga Str...      Beginner Yoga
# 3         Twist & Detox The Body - 30 min Yoga Class  Vinyasa Flow Yoga
# 4  Yoga For Sleep - Restorative Yoga For A Good N...  Vinyasa Flow Yoga
#
#    YogaChallenge release_date release_time duration  viewCount  likeCount  \
# 0          False   2013-04-21     20:24:47    03:44      17409        337
# 1          False   2014-04-05     17:08:58    24:24      37100        614
# 2          False   2014-04-06     18:25:20    01:11     310255       2710
# 3          False   2014-04-06     03:32:06    31:54      27571        589
# 4          False   2014-04-09     13:36:00    25:10      47471        626
#
#    commentCount defaultLAudioLanguage videoCategoryLabel  engagement_ratio
# 0          32.0                 en-US             Sports          0.021196
# 1          23.0                 en-US             Sports          0.017170
# 2         186.0                    en      Howto & Style          0.009334
# 3          27.0                 en-US             Sports          0.022342
# 4          32.0                 en-US             Sports          0.013861

# %%
# any null values?
df.isna().sum()
# Out:
# channelTitle             0
# videoId                  0
# videoTitle               0
# yogaSubject              0
# YogaChallenge            0
# release_date             0
# release_time             0
# duration                 0
# viewCount                0
# likeCount                0
# commentCount             0
# defaultLAudioLanguage    0
# videoCategoryLabel       0
# engagement_ratio         1
# dtype: int64

# %%
# why is there a missing engagement ratio? 

df[df['engagement_ratio'].isna()]
# Out:
#             channelTitle      videoId                       videoTitle  \
# 595  Yoga with Kassandra  MJR2QvajPP0  Yoga with Kassandra Live Stream
#
#     yogaSubject  YogaChallenge release_date release_time duration  viewCount  \
# 595       Other          False   2021-09-07     12:13:45    00:00          0
#
#      likeCount  commentCount defaultLAudioLanguage videoCategoryLabel  \
# 595          0           0.0                    en      Howto & Style
#
#      engagement_ratio
# 595               NaN

# %%
df = df[df['viewCount']>0].reset_index(drop=True)
df.tail()
# Out:
#             channelTitle      videoId  \
# 847  Yoga with Kassandra  bN5l0JJTOLw
# 848  Yoga with Kassandra  C2RAjUEAoLI
# 849  Yoga with Kassandra  XcXDqvQXgIs
# 850  Yoga with Kassandra  I9YJA0zL4yg
# 851  Yoga with Kassandra  6INXj5B5uqE
#
#                                             videoTitle        yogaSubject  \
# 847  20 min Intermediate Yoga Flow - Minimal Cues S...  Intermediate Yoga
# 848  10 min Gentle Morning Yoga for Beginners (NO P...       Morning Yoga
# 849  25 min Fire Element Yoga Flow - Core, Twists &...        Zodiac yoga
# 850  25 min Earth Element Yoga - Grounding, Strengt...        Zodiac yoga
# 851    15 min Morning Yoga Flow - All Levels, No Props       Morning Yoga
#
#      YogaChallenge release_date release_time duration  viewCount  likeCount  \
# 847          False   2024-02-12     11:15:04    21:20      72164       4237
# 848          False   2024-02-19     11:15:00    11:18     161923       6662
# 849          False   2024-02-26     11:15:01    24:52      63923       3142
# 850          False   2024-03-04     11:15:01    25:23      69360       4239
# 851          False   2024-03-11     10:15:00    17:08      72861       4585
#
#      commentCount defaultLAudioLanguage videoCategoryLabel  engagement_ratio
# 847         279.0                    en      Howto & Style          0.062580
# 848         180.0                    en      Howto & Style          0.042255
# 849         206.0                    en      Howto & Style          0.052376
# 850         266.0                    en      Howto & Style          0.064951
# 851         282.0                    en      Howto & Style          0.066798

# %% [markdown]
# We have our data ready for extracting titles now.
#
# For this part, I will be using a separate dataframe with only `videoTitle` and `engagement_ratio` columns.

# %%
df_title = df[['videoTitle','engagement_ratio']]
df_title.head()
# Out:
#                                           videoTitle  engagement_ratio
# 0                          Yoga Timelapse - Fidelity          0.021196
# 1  Intermediate Yoga Core Workout - 30 min Vinyas...          0.017170
# 2  1 Hour Yin Yoga - Beginners Full Body Yoga Str...          0.009334
# 3         Twist & Detox The Body - 30 min Yoga Class          0.022342
# 4  Yoga For Sleep - Restorative Yoga For A Good N...          0.013861

# %%
# function to clean up text and remove any special characters
import re

def clean_text(content):
    '''
    clean the text by removing 
    special characters with regex.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", content).split())

# %%
df_title['clean_titles'] = [clean_text(title) for title in df_title['videoTitle']] 
df_title.head()
# Out:
# /var/folders/qn/18pqdj6j4y5bmd8j80dlz0n80000gn/T/ipykernel_2014/2855319375.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_title['clean_titles'] = [clean_text(title) for title in df_title['videoTitle']]
#                                           videoTitle  engagement_ratio  \
# 0                          Yoga Timelapse - Fidelity          0.021196
# 1  Intermediate Yoga Core Workout - 30 min Vinyas...          0.017170
# 2  1 Hour Yin Yoga - Beginners Full Body Yoga Str...          0.009334
# 3         Twist & Detox The Body - 30 min Yoga Class          0.022342
# 4  Yoga For Sleep - Restorative Yoga For A Good N...          0.013861
#
#                                         clean_titles
# 0                            Yoga Timelapse Fidelity
# 1  Intermediate Yoga Core Workout 30 min Vinyasa ...
# 2   1 Hour Yin Yoga Beginners Full Body Yoga Stretch
# 3             Twist Detox The Body 30 min Yoga Class
# 4  Yoga For Sleep Restorative Yoga For A Good Nig...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import nltk

# Initialize lemmatizer and stopwords
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# Function to lemmatize and preprocess text
def preprocess_title(title):
    tokens = title.lower().split()  # Tokenize and convert to lowercase
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words and word.isalnum()]  # Lemmatize and remove stopwords
    return ' '.join(tokens)

# Apply preprocessing to the titles
df_title['lemmatized_titles'] = df_title['clean_titles'].apply(preprocess_title)

# Tokenize and preprocess titles using CountVectorizer
vectorizer = CountVectorizer(stop_words='english')  # Automatically removes stopwords
X = vectorizer.fit_transform(df_title['lemmatized_titles'])  # Create word frequency matrix
keywords = vectorizer.get_feature_names_out()  # Extract unique tokens (keywords)

# Convert word matrix to DataFrame
keywords_df = pd.DataFrame(X.toarray(), columns=keywords)

# Combine with the original DataFrame
df_keywords = pd.concat([df_title, keywords_df], axis=1)
# Out:
# /var/folders/qn/18pqdj6j4y5bmd8j80dlz0n80000gn/T/ipykernel_2014/782125571.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_title['lemmatized_titles'] = df_title['clean_titles'].apply(preprocess_title)

# %%
# Calculate engagement ratio metrics for each keyword
keyword_impact = {}

for keyword in keywords:
    count_engagement = df_keywords[df_keywords[keyword] == 1]['engagement_ratio'].count()
    mean_engagement = df_keywords[df_keywords[keyword] == 1]['engagement_ratio'].mean()
    std_engagement = df_keywords[df_keywords[keyword] == 1]['engagement_ratio'].std()
    keyword_impact[keyword] = [count_engagement, mean_engagement, std_engagement]

# Convert to DataFrame for visualization
keyword_impact_df = pd.DataFrame.from_dict(keyword_impact, orient='index', columns=['Count', 'Mean Engagement Ratio', 'Standard Deviation'])
keyword_impact_df = keyword_impact_df.reset_index().rename(columns={'index': 'Keyword'}).sort_values(by='Count', ascending=False)
keyword_impact_df.reset_index(drop=True, inplace=True)
keyword_impact_df = keyword_impact_df[keyword_impact_df['Count']>0]

# %%
keyword_impact_df
# Out:
#        Keyword  Count  Mean Engagement Ratio  Standard Deviation
# 0          min    468               0.029511            0.010132
# 1         yoga    419               0.030532            0.011864
# 2      stretch    225               0.028922            0.008648
# 3      morning    193               0.031467            0.008101
# 4           30    165               0.028615            0.010441
# ..         ...    ...                    ...                 ...
# 813        eat      1               0.035006                 NaN
# 814  muladhara      1               0.013469                 NaN
# 815       erin      1               0.030720                 NaN
# 816     moving      1               0.029030                 NaN
# 817       melt      1               0.037754                 NaN
#
# [818 rows x 4 columns]

# %%
# our dataset is ready now; we can save it 

keyword_impact_df.to_csv("title_words.csv",index=False)
